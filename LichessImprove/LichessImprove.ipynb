# %%
# Out:
# \\wsl$\Ubuntu-20.04\home\leoocode\LichessImprove\LichessImprove
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# \\wsl$\Ubuntu-20.04\home\leoocode\LichessImprove\LichessImprove\main.py in <module>
#      22     user_games = lichess.user_games(name, max=2, format=PGN)
#      23
# ---> 24     with engine.SimpleEngine.popen_uci("/usr/games/stockfish") as stockfish:
#      25
#      26         data = pd.DataFrame(columns=[x for x in range(1, 51)])
#
# c:\users\leort\appdata\local\programs\python\python38-32\lib\site-packages\chess\engine.py in popen_uci(cls, command, timeout, debug, setpgrp, **popen_args)
#    2753         Returns a :class:`~chess.engine.SimpleEngine` instance.
#    2754         """
# -> 2755         return cls.popen(UciProtocol, command, timeout=timeout, debug=debug, setpgrp=setpgrp, **popen_args)
#    2756
#    2757     @classmethod
#
# ...
